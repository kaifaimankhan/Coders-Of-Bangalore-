# %% [markdown]
# # Coders of bangalore
#
# You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
#
# He asks you where you live, and finally, after talking to you, gives you a challenging task
#
# Collect raw Instagram data of all OpenAI followers
#
# Answer these questions:
#
# Who has the maximum posts
# who has the maximum followers
# Who follows the maximum people
# How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# You have 24 hours!
#
# You then ask for data - he laughs!

# %% [markdown]
# # Data Colection
# You hire Vijyalaxmi Iyer and Sam Chandra to help with the project. Vijyalaxmi lives all the way in Hebbal, and Sam stays in HSR Layout, so meeting at either place would be a long trip for someone. To keep things fair, you decide to set up a meeting at Rameshwaram Café in Indiranagar, a perfect midway point.
#
# Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# Laxmi and Sam will be in charge of collecting the Instagram follower data.
# You will build the Python Script that will process everything.
# By the end of the meeting, everyone is aligned: Laxmi and Sam will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly. The team is ready, the plan is set, and the project officially kicks off.

# %% [markdown]
# While Laxmi and Sam are collecting the real data, we continue building the core of our project using a simple demo dataset. This lets us solidify the parsing logic so that the moment the actual field data arrives, the program will already be ready to handle it.
#
# We begin by loading the demo text file. The file contains multiple profiles, each separated by an empty lin

# %%
with open("finaldata.txt",encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3]

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)
             

    
        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)

            
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
       
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, "type_of_page":type_of_page, 
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

# %%
all_data = []
for c in chunks:
    all_data.append(parse_chunk(c))

# %%
import json
s = json.dumps(all_data, indent=4) 
with open("data.json", "w") as f:
    f.write(s)

# %% [markdown]
# # Who has the maximum post
# lets write code to find max post

# %%
max_posts = max(all_data, key=lambda x:int(x["no_of_posts"]))
print(f"{max_posts['username']},has {max_posts['no_of_posts']} posts")
# Out:
# startuphub_blr,has 2300 posts

# %% [markdown]
# # Who has maximim followers
# lets write code to find max followers

# %%
max_followers = max(all_data, key=lambda x: int(x["no_of_followers"]))
print(f"{max_followers['username']},has {max_followers['no_of_followers']} followers")
# Out:
# _anujsinghal,has 681000 followers

# %% [markdown]
# # Who has maximim following
# lets write code to find max Following

# %%
max_followers = max(all_data, key=lambda x: int(x["no_of_following"]))
max_followers
# Out:
# {'username': 'bangalore_tech_bro',
#  'no_of_posts': 402,
#  'no_of_followers': 12500,
#  'type_of_page': 'Entrepreneur',
#  'no_of_following': 890,
#  'name': 'Rahul | HSR Hustler',
#  'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# # How many categories
# lets write a code to find how many catagories

# %%
categories = {chunk['type_of_page'] for chunk in all_data}
print(f"There are {len(categories)} cetegories")
# Out:
# There are 34 cetegories

# %% [markdown]
# # Analyzing the Final Collected Data
# So finally the actual dataset prepared by Sam and Vijaylaxmi is ready, and today we run our program on their real collected data instead of the demo file we used earlier. The workflow remains the same, which is the whole point of building a clean parsing pipeline from the start.
#
# The main difference in the code is that we now load the final data file they shared instead of initialdata.txt.
#
# Everything that follows is identical. We split the content into chunks, parse each chunk into a dictionary and then run the same analysis loops to find the highest posts, highest followers, highest following and the set of all categories.
#
# Since the structure of the data stayed consistent, nothing else in the code had to change. The parser works, the analysis works, and the final dataset runs smoothly through the entire pipeline
